# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
train_data = pd.read_csv("../data/train.csv")
test_data = pd.read_csv("../data/test.csv")

# %%
# data = pd.read_csv('../data/resampled_data.csv')
data = pd.concat([train_data, test_data], ignore_index=True)

# %%
plt.figure(figsize=(20, 6))
sns.countplot(data=data, x='category', order=data['category'].value_counts().index, palette='viridis')
plt.title("Category Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/_h/z3c93qf1713871kq28vb6b7c0000gn/T/ipykernel_42835/3555245906.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='category', order=data['category'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x=data['sub_category'].value_counts().index, y=data['sub_category'].value_counts().values, palette="viridis")
plt.title("Sub-Category Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/_h/z3c93qf1713871kq28vb6b7c0000gn/T/ipykernel_42835/534800415.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['sub_category'].value_counts().index, y=data['sub_category'].value_counts().values, palette="viridis")

# %%
plt.figure(figsize=(14, 8))
sns.countplot(data=data, y='sub_category', hue='category', dodge=False)
plt.title("Category-Sub-Category Distribution")
plt.legend(title='Category')
plt.show()

# %%
text = " ".join(data['crimeaditionalinfo'].astype(str))

plt.figure(figsize=(10, 8))
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Top Words in Crime Information")
plt.show()

# %%
category_summary = data.groupby('category').size().reset_index(name='Count').sort_values('Count', ascending=False)
subcategory_summary = data.groupby('sub_category').size().reset_index(name='Count').sort_values('Count', ascending=False)

# %%
print("Category Summary Table")
print(category_summary)
# Out:
# Category Summary Table
#                                              category  Count
# 8                              Online Financial Fraud  76330
# 10              Online and Social Media Related Crime  16279
# 0                               Any Other Cyber Crime  14548
# 4                      Cyber Attack/ Dependent Crimes   4869
# 12          RapeGang Rape RGRSexually Abusive Content   3734
# 15                          Sexually Obscene material   2504
# 6      Hacking  Damage to computercomputer system etc   2302
# 14                              Sexually Explicit Act   2087
# 3                                Cryptocurrency Crime    646
# 9                            Online Gambling  Betting    578
# 1   Child Pornography CPChild Sexual Abuse Materia...    502
# 7                            Online Cyber Trafficking    244
# 5                                     Cyber Terrorism    213
# 11                                         Ransomware     74
# ...

# %%
print("\nSub-Category Summary Table")
print(subcategory_summary)
# Out:
# Sub-Category Summary Table
#                                          sub_category  Count
# 35                                 UPI Related Frauds  35746
# 27                                              Other  14548
# 10               DebitCredit Card FraudSim Swap Fraud  14361
# 20                     Internet Banking Related Fraud  11845
# 17                                  Fraud CallVishing   7630
# 6                   Cyber Bullying  Stalking  Sexting   5455
# 14                              EWallet Related Fraud   5385
# 16                          FakeImpersonating Profile   3062
# 28                     Profile Hacking Identity Theft   2824
# 2                           Cheating by Impersonation   2707
# 36                     Unauthorised AccessData Breach   1484
# 24                                   Online Job Fraud   1206
# 11                              DematDepository Fraud    983
# 34           Tampering with computer source documents    761
# ...
